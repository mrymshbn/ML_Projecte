# %% [markdown]
# import pandas as pd
#
# # خواندن دیتاست
# df = pd.read_csv('Data_p1.csv')
#
# # محاسبه زمان نسبی از صفر
# df['RELATIVE_TIME'] = df['PASSDATETIME'] - df['PASSDATETIME'].min()
#
# # مرتب‌سازی بر اساس زمان نسبی به صورت صعودی
# df_sorted = df.sort_values('RELATIVE_TIME', ascending=True)
#
# # انتخاب 50 تا از داده‌های مرتب شده
# df_subset = df_sorted.head(50)
#
# # گروه‌بندی بر اساس شناسه ماشین
# grouped = df_subset.groupby('vehicleId')
#
# # نمایش زوج‌های مرتب براساس شناسه ماشین و تکرارهای آن
# for group, data in grouped:
#     vehicle_id = group
#     print(f"Vehicle ID: {vehicle_id}")
#
#     # تعداد تکرارهای شناسه ماشین
#     count = data.shape[0]
#     print(f"Count: {count}")
#
#     # نمایش زمان و شناسه حسگر
#     for index, row in data.iterrows():
#         passdatetime_id = row['PASSDATETIME']
#         device_id = row['DEVICEID']
#         print(f"PASSDATETIME ID: {passdatetime_id}, Device ID: {device_id}")
#
#     print()

# %% [markdown]
# import pandas as pd
#
# # خواندن دیتاست
# df = pd.read_csv('Data_p1.csv')
#
# # محاسبه زمان نسبی از صفر
# df['RELATIVE_TIME'] = df['PASSDATETIME'] - df['PASSDATETIME'].min()
#
# # انتخاب 50 نمونه تصادفی
# df_sampled = df.sample(n=50)
#
# # گروه‌بندی بر اساس شناسه ماشین
# grouped = df_sampled.groupby('vehicleId')
#
# # نمایش زوج‌های مرتب براساس شناسه ماشین و تکرارهای آن
# for group, data in grouped:
#     vehicle_id = group
#     print(f"Vehicle ID: {vehicle_id}")
#
#     # تعداد تکرارهای شناسه ماشین
#     count = data.shape[0]
#     print(f"Count: {count}")
#
#     # نمایش زمان و شناسه حسگر
#     for index, row in data.iterrows():
#         passdatetime_id = row['PASSDATETIME']
#         device_id = row['DEVICEID']
#         print(f"PASSDATETIME ID: {passdatetime_id}, Device ID: {device_id}")
#
#     print()

# %%
import pandas as pd

# خواندن دیتاست
df = pd.read_csv('Data_p1.csv')

# محاسبه زمان نسبی از صفر
df['RELATIVE_TIME'] = df['PASSDATETIME'] - df['PASSDATETIME'].min()

# گروه‌بندی بر اساس شناسه ماشین و محاسبه تعداد تکرارها
counts = df['vehicleId'].value_counts()

# انتخاب 50 نمونه با تعداد تکرار بیشتر از 1
df_sampled = df[df['vehicleId'].isin(counts[counts > 1].index)].sample(n=50)

# گروه‌بندی بر اساس شناسه ماشین
grouped = df_sampled.groupby('vehicleId')

# نمایش زوج‌های مرتب براساس شناسه ماشین و تکرارهای آن
for group, data in grouped:
    vehicle_id = group
    print(f"Vehicle ID: {vehicle_id}")
    
    # تعداد تکرارهای شناسه ماشین
    count = data.shape[0]
    print(f"Count: {count}")
    
    # نمایش زمان و شناسه حسگر
    for index, row in data.iterrows():
        passdatetime_id = row['PASSDATETIME']
        device_id = row['DEVICEID']
        print(f"PASSDATETIME ID: {passdatetime_id}, Device ID: {device_id}")

    print()
# Out:
# Vehicle ID: 13095438103
# Count: 1
# PASSDATETIME ID: 54869, Device ID: 73414
#
# Vehicle ID: 15709509817
# Count: 1
# PASSDATETIME ID: 394903, Device ID: 39198
#
# Vehicle ID: 78417081197
# Count: 1
# PASSDATETIME ID: 395199, Device ID: 80022
#
# Vehicle ID: 81612393497
# Count: 1
# PASSDATETIME ID: 302930, Device ID: 37308
#
# Vehicle ID: 81792267010
# Count: 1
# PASSDATETIME ID: 409177, Device ID: 102674
#
# Vehicle ID: 82913336394
# Count: 1
# PASSDATETIME ID: 20327, Device ID: 80085
#
# Vehicle ID: 83955054127
# Count: 1
# PASSDATETIME ID: 54625, Device ID: 43041
#
# Vehicle ID: 87965868217
# Count: 1
# PASSDATETIME ID: 408446, Device ID: 78531
#
# Vehicle ID: 90062639717
# Count: 1
# PASSDATETIME ID: 50745, Device ID: 100266
#
# Vehicle ID: 90290634167
# Count: 1
# PASSDATETIME ID: 314480, Device ID: 42880
#
# Vehicle ID: 91696389197
# Count: 1
# PASSDATETIME ID: 335929, Device ID: 78524
#
# Vehicle ID: 97638058017
# Count: 1
# PASSDATETIME ID: 415568, Device ID: 98537
#
# Vehicle ID: 100146739377
# Count: 1
# PASSDATETIME ID: 417109, Device ID: 43027
#
# Vehicle ID: 103887576014
# Count: 1
# PASSDATETIME ID: 424956, Device ID: 73778
#
# Vehicle ID: 105795844530
# Count: 1
# PASSDATETIME ID: 12175, Device ID: 80141
#
# Vehicle ID: 110404677107
# Count: 1
# PASSDATETIME ID: 350696, Device ID: 42663
#
# Vehicle ID: 110877661207
# Count: 1
# PASSDATETIME ID: 345866, Device ID: 92538

# %%
import pandas as pd

# خواندن دیتاست
df = pd.read_csv('Data_p1.csv')

# محاسبه زمان نسبی از صفر
df['RELATIVE_TIME'] = df['PASSDATETIME'] - df['PASSDATETIME'].min()

# گروه‌بندی بر اساس شناسه ماشین و محاسبه تعداد تکرارها
counts = df['vehicleId'].value_counts()

# انتخاب 50 نمونه با تعداد تکرار بیشتر از 1
df_sampled = df[df['vehicleId'].isin(counts[counts > 1].index)].sample(n=50)

# مرتب‌سازی بر اساس زمان نسبی به صورت صعودی و شناسه ماشین
df_sorted = df_sampled.sort_values(['RELATIVE_TIME', 'vehicleId'], ascending=True)

# گروه‌بندی بر اساس شناسه ماشین
grouped = df_sorted.groupby('vehicleId')

# نمایش توالی حسگرها و دوربین بعدی براساس شناسه ماشین
for group, data in grouped:
    vehicle_id = group
    print(f"Vehicle ID: {vehicle_id}")
    
    # نمایش توالی حسگرها و دوربین بعدی
    next_camera_id = data['DEVICEID'].shift(-1)
    for index, row in data.iterrows():
        device_id = row['DEVICEID']
        next_camera = next_camera_id[index]
        print(f"Device ID: {device_id}, Next Camera ID: {next_camera}")

    print()
# Out:
# Vehicle ID: 13207811970
# Device ID: 41914, Next Camera ID: nan
#
# Vehicle ID: 20462662717
# Device ID: 73792, Next Camera ID: nan
#
# Vehicle ID: 21070851317
# Device ID: 42054, Next Camera ID: nan
#
# Vehicle ID: 22152682807
# Device ID: 98782, Next Camera ID: nan
#
# Vehicle ID: 24206639850
# Device ID: 76312, Next Camera ID: nan
#
# Vehicle ID: 24215227850
# Device ID: 44021, Next Camera ID: nan
#
# Vehicle ID: 27033618480
# Device ID: 79091, Next Camera ID: nan
#
# Vehicle ID: 27235522247
